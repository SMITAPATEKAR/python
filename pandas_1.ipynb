# %%
import pandas as pd

# %%
# read file in diffrent way

# %%
A=pd.read_csv('a.txt')                                           # in csv

# %%
A
# Out:
#        Name  Age    Sal
# 0     payal   27  12000
# 1     komal   24  20000
# 2  prajakta   21  24000
# 3     pooja   20  15000

# %%
B=pd.read_excel('b.xlsx')                                        # in excel

# %%
B
# Out:
#        Name  Age    Sal
# 0     payal   20  12000
# 1     komal   22  20000
# 2  prajakta   18  25000
# 3     pooja   25  15000

# %%
py_dict={'Name':('payal','komal','prajakta','pooja'),
        'Age':(27,20,18,26),
        'Sal':(12000,25000,20000,15000)}

# %%
C=pd.DataFrame(py_dict)                                       # in Dataframe

# %%
C
# Out:
#        Name  Age    Sal
# 0     payal   27  12000
# 1     komal   20  25000
# 2  prajakta   18  20000
# 3     pooja   26  15000

# %%
p={('payal','komal','prajakta','pooja'),
   (27,20,18,26),
   (12000,25000,20000,15000)
  }

# %%
p
# Out:
# {('payal', 'komal', 'prajakta', 'pooja'),
#  (12000, 25000, 20000, 15000),
#  (27, 20, 18, 26)}

# %%
P=pd.DataFrame(p)

# %%
P
# Out:
#        0      1         2      3
# 0  payal  komal  prajakta  pooja
# 1     27     20        18     26
# 2  12000  25000     20000  15000

# %%
P=pd.DataFrame(p,columns=['a','b','c','d'])                            # add columns name

# %%
P
# Out:
#        a      b         c      d
# 0  payal  komal  prajakta  pooja
# 1     27     20        18     26
# 2  12000  25000     20000  15000

# %%
# conveted into other format

# %%
A.to_excel('test12.xlsx')

# %%
A
# Out:
#        Name  Age    Sal
# 0     payal   27  12000
# 1     komal   24  20000
# 2  prajakta   21  24000
# 3     pooja   20  15000

# %%
A.to_html('as.html')

# %%
A
# Out:
#        Name  Age    Sal
# 0     payal   27  12000
# 1     komal   24  20000
# 2  prajakta   21  24000
# 3     pooja   20  15000

# %%
A.set_index('Age')
# Out:
#          Name    Sal
# Age
# 27      payal  12000
# 24      komal  20000
# 21   prajakta  24000
# 20      pooja  15000

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is F2BB-D4C2
#
#  Directory of C:\Users\patek\OneDrive\Desktop\ML32
#
# 27-04-2023  21:42    <DIR>          .
# 26-04-2023  19:55    <DIR>          ..
# 27-04-2023  21:04    <DIR>          .ipynb_checkpoints
# 27-04-2023  21:14                79 a.txt
# 27-04-2023  21:40               594 as.html
# 27-04-2023  21:17             8,837 b.xlsx
# 10-11-2022  22:40           938,020 Bengaluru_House_Data.csv
# 19-11-2022  09:13            15,744 covid.xlsx
# 19-11-2022  09:21            19,334 covid12.xlsx
# 26-04-2023  19:56                54 details1.txt
# 11-11-2022  12:42           627,115 df1.xlsx
# 09-11-2022  08:55                47 pand.csv
# 10-11-2022  11:24             9,792 panda.xlsx
# 10-11-2022  22:55            61,826 pandas1.ipynb
# 12-11-2022  17:41            83,487 pandas2.ipynb
# 17-11-2022  21:01            47,172 pandas3.ipynb
# 26-04-2023  20:08             9,809 PS.xlsx
# ...

# %%
df=pd.read_csv('Bengaluru_House_Data.csv')

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.shape
# Out:
# (13320, 9)

# %%
row,col=df.shape

# %%
row
# Out:
# 13320

# %%
col
# Out:
# 9

# %%
df['area_type']
# Out:
# 0        Super built-up  Area
# 1                  Plot  Area
# 2              Built-up  Area
# 3        Super built-up  Area
# 4        Super built-up  Area
#                  ...
# 13315          Built-up  Area
# 13316    Super built-up  Area
# 13317          Built-up  Area
# 13318    Super built-up  Area
# 13319    Super built-up  Area
# Name: area_type, Length: 13320, dtype: object

# %%
df[['area_type','location','size']]
# Out:
#                   area_type                  location       size
# 0      Super built-up  Area  Electronic City Phase II      2 BHK
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area               Uttarahalli      3 BHK
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK
# 4      Super built-up  Area                  Kothanur      2 BHK
# ...                     ...                       ...        ...
# 13315        Built-up  Area                Whitefield  5 Bedroom
# 13316  Super built-up  Area             Richards Town      4 BHK
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK
# 13319  Super built-up  Area              Doddathoguru      1 BHK
#
# [13320 rows x 3 columns]

# %%
df['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
df['area_type'].value_counts()
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64

# %%
df['test']=df['price']*5

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price     test
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07   195.35
# ...

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price     test
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07   195.35
# ...

# %%
df.drop('size',axis=1)
# Out:
#                   area_type   availability  society total_sqft  bath  balcony  \
# 0      Super built-up  Area         19-Dec  Coomee        1056   2.0      1.0
# 1                Plot  Area  Ready To Move  Theanmp       2600   5.0      3.0
# 2            Built-up  Area  Ready To Move      NaN       1440   2.0      3.0
# 3      Super built-up  Area  Ready To Move  Soiewre       1521   3.0      1.0
# 4      Super built-up  Area  Ready To Move      NaN       1200   2.0      1.0
# ...                     ...            ...      ...        ...   ...      ...
# 13315        Built-up  Area  Ready To Move  ArsiaEx       3453   4.0      0.0
# 13316  Super built-up  Area  Ready To Move      NaN       3600   5.0      NaN
# 13317        Built-up  Area  Ready To Move  Mahla T       1141   2.0      1.0
# 13318  Super built-up  Area         18-Jun  SollyCl       4689   4.0      1.0
# 13319  Super built-up  Area  Ready To Move      NaN        550   1.0      1.0
#
#         price     test
# ...

# %%
df=df.drop('location',axis=1)

# %%
df
# Out:
#                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 2            Built-up  Area  Ready To Move      3 BHK      NaN       1440
# 3      Super built-up  Area  Ready To Move      3 BHK  Soiewre       1521
# 4      Super built-up  Area  Ready To Move      2 BHK      NaN       1200
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#        bath  balcony   price     test
# 0       2.0      1.0   39.07   195.35
# ...

# %%
df.drop('location',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14204\2717326878.py in <module>
# ----> 1 df.drop('location',axis=1,inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.drop([2,3,4],inplace=True)

# %%
df
# Out:
#                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 5      Super built-up  Area  Ready To Move      2 BHK  DuenaTa       1170
# 6      Super built-up  Area         18-May      4 BHK  Jaades        2732
# 7      Super built-up  Area  Ready To Move      4 BHK  Brway G       3300
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#        bath  balcony   price     test
# 0       2.0      1.0   39.07   195.35
# ...

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'size', 'society', 'total_sqft', 'bath',
#        'balcony', 'price', 'test'],
#       dtype='object')

# %%
col=[col for col in df.columns if not col.startswith('b')]

# %%
col
# Out:
# ['area_type', 'availability', 'size', 'society', 'total_sqft', 'price', 'test']

# %%
df[col]
# Out:
#                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 5      Super built-up  Area  Ready To Move      2 BHK  DuenaTa       1170
# 6      Super built-up  Area         18-May      4 BHK  Jaades        2732
# 7      Super built-up  Area  Ready To Move      4 BHK  Brway G       3300
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#         price     test
# 0       39.07   195.35
# 1      120.00   600.00
# ...

# %%
col=[col for col in df.columns if col.startswith('b')]

# %%
col
# Out:
# ['bath', 'balcony']

# %%
df[col]
# Out:
#        bath  balcony
# 0       2.0      1.0
# 1       5.0      3.0
# 5       2.0      1.0
# 6       4.0      NaN
# 7       4.0      NaN
# ...     ...      ...
# 13315   4.0      0.0
# 13316   5.0      NaN
# 13317   2.0      1.0
# 13318   4.0      1.0
# 13319   1.0      1.0
#
# [13317 rows x 2 columns]

# %%
import pandas as pd

# %%
A=pd.read_csv('a.txt')

# %%
A
# Out:
#        Name  Age    Sal
# 0     payal   27  12000
# 1     komal   24  20000
# 2  prajakta   21  24000
# 3     pooja   20  15000

# %%
s=pd.Series(['m','m','f'],name='gen')

# %%
s
# Out:
# 0    m
# 1    m
# 2    f
# Name: gen, dtype: object

# %%
df=pd.concat([A,s],axis=1)

# %%
df
# Out:
#        Name  Age    Sal  gen
# 0     payal   27  12000    m
# 1     komal   24  20000    m
# 2  prajakta   21  24000    f
# 3     pooja   20  15000  NaN

# %%
df['new_gen']=df['gen'].map({'m':1,'f':0})                                        #using dict method

# %%
df
# Out:
#        Name  Age    Sal  gen  new_gen
# 0     payal   27  12000    m      1.0
# 1     komal   24  20000    m      1.0
# 2  prajakta   21  24000    f      0.0
# 3     pooja   20  15000  NaN      NaN

# %%
def encode(r):
    if r=='m':
        return 0
    elif r=='f':
        return 1
    else:
        return None

# %%
df['New_gen']=df['gen'].map(encode)

# %%
df
# Out:
#        Name  Age    Sal  gen  new_gen  New_gen
# 0     payal   27  12000    m      1.0      0.0
# 1     komal   24  20000    m      1.0      0.0
# 2  prajakta   21  24000    f      0.0      1.0
# 3     pooja   20  15000  NaN      NaN      NaN

# %%
df['New_gen']=df['gen'].map(lambda x: 1 if 'm' else 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2600\650457345.py in <module>
# ----> 1 df['New_gen']=df['gen'].map(lambda x: 1 if 'm' else 0)
#
# NameError: name 'df' is not defined

# %%
df

# %%
df['New_gen']=df['gen'].map(lambda x: 1 if x=='m' else 0)

# %%
df

# %%
df.drop(3,inplace=True)
